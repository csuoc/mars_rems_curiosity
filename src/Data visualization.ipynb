# %% [markdown]
# # Import box

# %%
import plotly.express as px
import plotly.graph_objects as go
from ipynb.fs.full.Data_cleaning import call_Curiosity, get_pictures_Curiosity

# %%
weather_cleaned = pd.read_csv("../data/mars-weather-cleaned.csv")
weather_cleaned
# Out:
#       Earth Date   Sol  Month  Min_temp (°C)  Max_temp (°C)  Pressure (Pa)  \
# 0     2018-02-27  1977      5          -77.0          -10.0          727.0
# 1     2018-02-26  1976      5          -77.0          -10.0          728.0
# 2     2018-02-25  1975      5          -76.0          -16.0          729.0
# 3     2018-02-24  1974      5          -77.0          -13.0          729.0
# 4     2018-02-23  1973      5          -78.0          -18.0          730.0
# ...          ...   ...    ...            ...            ...            ...
# 1889  2012-08-18    12      6          -76.0          -18.0          741.0
# 1890  2012-08-17    11      6          -76.0          -11.0          740.0
# 1891  2012-08-16    10      6          -75.0          -16.0          739.0
# 1892  2012-08-15     9      6            NaN            NaN            NaN
# 1893  2012-08-07     1      6            NaN            NaN            NaN
#
#       Atmo_opacity  Mean_temp (°C)  Season
# ...

# %%
max_temp = px.line(weather_cleaned[["Sol", "Min_temp (°C)", "Max_temp (°C)", "Mean_temp (°C)"]], x="Sol", y=["Max_temp (°C)", "Min_temp (°C)", "Mean_temp (°C)"])
max_temp.show()
# Out:
# <div>                            <div id="e56e3c26-e4d5-471a-be80-b3e716d94586" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e56e3c26-e4d5-471a-be80-b3e716d94586")) {                    Plotly.newPlot(                        "e56e3c26-e4d5-471a-be80-b3e716d94586",                        [{"hovertemplate":"variable=Max_temp (\u00b0C)<br>Sol=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Max_temp (\u00b0C)","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Max_temp (\u00b0C)","showlegend":true,"x":[1977,1976,1975,1974,1973,1972,1971,1970,1969,1968,1967,1966,1965,1964,1963,1962,1961,1960,1959,1958,1957,1956,1955,1954,1953,1952,1951,1950,1949,1948,1947,1946,1945,1944,1943,1942,1941,1940,1939,1938,1937,19
# ...

# %%
get_pictures_Curiosity("2022-10-01")
# Out:
# Image available for camera FHAZ onboard Curiosity rover: https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03609/opgs/edr/fcam/FLB_717897723EDR_F0971734FHAZ00337M_.JPG
# Image available for camera RHAZ onboard Curiosity rover: https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03609/opgs/edr/rcam/RLB_717897779EDR_F0971734RHAZ00337M_.JPG
# Image available for camera MAST onboard Curiosity rover: https://mars.nasa.gov/msl-raw-images/msss/03609/mcam/3609ML1028340040508613C00_DXXX.jpg
# Image available for camera CHEMCAM onboard Curiosity rover: https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03609/opgs/edr/ccam/CR0_717878045EDR_F0971734CCAM02609M_.JPG
# Image available for camera MAHLI onboard Curiosity rover: https://mars.nasa.gov/msl-raw-images/msss/03609/mhli/3609MH0004650011301122C00_DXXX.jpg
# No image available on 2022-10-01 for camera MARDI onboard Curiosity rover, please select another Sol day
# ...
